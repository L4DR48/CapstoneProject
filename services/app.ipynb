# %%
import sys, os



# Add the project root directory to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

#from tools.boxscore import BoxScoreMaker
from tools.boxscore2_0 import BoxScoreMaker
from tools.boxscore_analysis import BoxScoreAnalysis

#from tools.boxscore_parser import BoxScoreParser 
#from tools.ocr import OCR
import os
import json
from dotenv import load_dotenv
from google import genai
from google.genai import errors, types

load_dotenv()
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# Use flash for better JSON compliance
MODEL = "gemini-2.5-flash-lite"

# Test connection
print("🔄 Testing connection...")
response = client.models.generate_content(
    model=MODEL,
    contents='Respond with "Connection good, Great Success!"'
)
try:
    print(response.text)
except:
    print("Response not successful")
# Out:
# 🔄 Testing connection...
# Connection good, Great Success!

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
v2=BoxScoreMaker(client,MODEL)

# %%
v2.boxscore("test_boxscores/Test_FPB3.png", "Braga", "test_jsons/fpb_braga.json")

# %%
with open("test_jsons/fpb_braga.json", "r") as f:
    d1 = json.load(f)
print(json.dumps(d1, indent=1))
# Out:
# {
#  "Braga": {
#   "Team_Name": "Sporting Clube de Braga",
#   "Home_Game": true,
#   "Scores": [
#    {
#     "Total": [
#      {
#       "Home": 83
#      },
#      {
#       "Away": 80
#      }
#     ]
#    },
#    {
#     "1Q": [
#      {
#       "Home": 22
#      },
#      {
#       "Away": 21
#      }
#     ]
#    },
#    {
#     "2Q": [
#      {
#       "Home": 11
#      },
#      {
#       "Away": 26
#      }
#     ]
#    },
#    {
#     "3Q": [
#      {
#       "Home": 23
#      },
#      {
#       "Away": 15
#      }
#     ]
#    },
#    {
#     "4Q": [
#      {
#       "Home": 27
#      },
#      {
#       "Away": 18
#      }
#     ]
#    }
#   ],
#   "Players": [
#    {
#     "Number": 2,
#     "Player": "Delaney Blaylock",
#     "MIN": "28:41",
#     "FGM": 8,
#     "FGA": 17,
#     "FG%": 47.1,
#     "3PM": 3,
#     "3PA": 10,
#     "3P%": 30.0,
#     "FTM": 3,
#     "FTA": 4,
#     "FT%": 75.0,
#     "PTS": 22,
#     "AST": 2,
#     "REB": 4,
#     "OREB": 0,
#     "STL": 1,
#     "BLK": 0,
#     "TO": 3,
#     "PF": 4,
#     "+-": 14
#    },
#    {
#     "Number": 3,
#     "Player": "Jesse Bingham Ii",
#     "MIN": "25:00",
#     "FGM": 2,
#     "FGA": 6,
#     "FG%": 33.3,
#     "3PM": 0,
#     "3PA": 2,
#     "3P%": 0.0,
#     "FTM": 0,
#     "FTA": 2,
#     "FT%": 0.0,
#     "PTS": 4,
#     "AST": 3,
#     "REB": 2,
#     "OREB": 1,
#     "STL": 1,
#     "BLK": 1,
#     "TO": 0,
#     "PF": 0,
#     "+-": -11
#    },
#    {
#     "Number": 6,
#     "Player": "Carlos Cardoso",
#     "MIN": "31:03",
#     "FGM": 1,
#     "FGA": 7,
#     "FG%": 14.3,
#     "3PM": 0,
#     "3PA": 5,
#     "3P%": 0.0,
#     "FTM": 4,
#     "FTA": 4,
#     "FT%": 100.0,
#     "PTS": 6,
#     "AST": 2,
#     "REB": 3,
#     "OREB": 1,
#     "STL": 0,
#     "BLK": 0,
#     "TO": 2,
#     "PF": 3,
#     "+-": 10
#    },
#    {
#     "Number": 7,
#     "Player": "Seydougou Fofana",
#     "MIN": "29:24",
#     "FGM": 1,
#     "FGA": 5,
#     "FG%": 20.0,
#     "3PM": 0,
#     "3PA": 3,
#     "3P%": 0.0,
#     "FTM": 6,
#     "FTA": 6,
#     "FT%": 100.0,
#     "PTS": 8,
#     "AST": 2,
#     "REB": 9,
#     "OREB": 2,
#     "STL": 2,
#     "BLK": 1,
#     "TO": 0,
#     "PF": 4,
#     "+-": 3
#    },
#    {
#     "Number": 11,
#     "Player": "Ricardo Monteiro",
#     "MIN": "31:33",
#     "FGM": 6,
#     "FGA": 9,
#     "FG%": 66.7,
#     "3PM": 1,
#     "3PA": 3,
#     "3P%": 33.3,
#     "FTM": 7,
#     "FTA": 10,
#     "FT%": 70.0,
#     "PTS": 20,
#     "AST": 2,
#     "REB": 6,
#     "OREB": 0,
#     "STL": 2,
#     "BLK": 0,
#     "TO": 3,
#     "PF": 3,
#     "+-": 12
#    },
#    {
#     "Number": 1,
#     "Player": "Miguel Peixoto",
#     "MIN": "0:00",
#     "FGM": 0,
#     "FGA": 0,
#     "FG%": 0.0,
#     "3PM": 0,
#     "3PA": 0,
#     "3P%": 0.0,
#     "FTM": 0,
#     "FTA": 0,
#     "FT%": 0.0,
#     "PTS": 0,
#     "AST": 0,
#     "REB": 0,
#     "OREB": 0,
#     "STL": 0,
#     "BLK": 0,
#     "TO": 0,
#     "PF": 0,
#     "+-": 0
#    },
#    {
#     "Number": 5,
#     "Player": "Antonio Moreira",
#     "MIN": "10:07",
#     "FGM": 0,
#     "FGA": 2,
#     "FG%": 0.0,
#     "3PM": 0,
#     "3PA": 0,
#     "3P%": 0.0,
#     "FTM": 0,
#     "FTA": 0,
#     "FT%": 0.0,
#     "PTS": 0,
#     "AST": 0,
#     "REB": 3,
#     "OREB": 0,
#     "STL": 0,
#     "BLK": 0,
#     "TO": 1,
#     "PF": 1,
#     "+-": -4
#    },
#    {
#     "Number": 10,
#     "Player": "Broderick Robinson",
#     "MIN": "25:09",
#     "FGM": 5,
#     "FGA": 8,
#     "FG%": 62.5,
#     "3PM": 5,
#     "3PA": 7,
#     "3P%": 71.4,
#     "FTM": 2,
#     "FTA": 4,
#     "FT%": 50.0,
#     "PTS": 17,
#     "AST": 8,
#     "REB": 4,
#     "OREB": 0,
#     "STL": 1,
#     "BLK": 0,
#     "TO": 1,
#     "PF": 2,
#     "+-": 0
#    },
#    {
#     "Number": 18,
#     "Player": "Eduardo Samuco",
#     "MIN": "0:00",
#     "FGM": 0,
#     "FGA": 0,
#     "FG%": 0.0,
#     "3PM": 0,
#     "3PA": 0,
#     "3P%": 0.0,
#     "FTM": 0,
#     "FTA": 0,
#     "FT%": 0.0,
#     "PTS": 0,
#     "AST": 0,
#     "REB": 0,
#     "OREB": 0,
#     "STL": 0,
#     "BLK": 0,
#     "TO": 0,
#     "PF": 0,
#     "+-": 0
#    },
#    {
#     "Number": 21,
#     "Player": "Somtochukwu Diman\u00f6chie",
#     "MIN": "5:23",
#     "FGM": 1,
#     "FGA": 4,
#     "FG%": 25.0,
#     "3PM": 0,
#     "3PA": 1,
#     "3P%": 0.0,
#     "FTM": 0,
#     "FTA": 0,
#     "FT%": 0.0,
#     "PTS": 2,
#     "AST": 1,
#     "REB": 2,
#     "OREB": 1,
#     "STL": 0,
#     "BLK": 0,
#     "TO": 0,
#     "PF": 2,
#     "+-": 0
#    },
#    {
#     "Number": 33,
#     "Player": "C\u00e2ndido S\u00e1",
#     "MIN": "13:40",
#     "FGM": 1,
#     "FGA": 5,
#     "FG%": 20.0,
#     "3PM": 0,
#     "3PA": 2,
#     "3P%": 0.0,
#     "FTM": 2,
#     "FTA": 2,
#     "FT%": 100.0,
#     "PTS": 4,
#     "AST": 1,
#     "REB": 3,
#     "OREB": 1,
#     "STL": 1,
#     "BLK": 1,
#     "TO": 1,
#     "PF": 1,
#     "+-": -9
#    }
#   ]
#  }
# }

# %%
ba=BoxScoreAnalysis(client,MODEL)

# %%
print(ba.boxscore_analysis(d1))
# Out:
# This was a nail-biter, a game where Sporting Clube de Braga had to dig deep to secure a home victory. Let's break down the boxscore with five key insights, focusing on their offensive and defensive performance:
#
# **Offensive Insights:**
#
# 1.  **Explosive Fourth Quarter Offense Secures the Win:** Braga's offense was a tale of two halves, but their ability to explode in the fourth quarter (27 points) was the deciding factor. After a strong first quarter and a dismal second, they found their rhythm again in the third (23 points) and then put the game away in the final frame. This demonstrates a clutch offensive capability and the ability to execute under pressure, a crucial trait for winning close games.
#
# 2.  **Star Power and Efficiency from Blaylock and Monteiro:** Delaney Blaylock and Ricardo Monteiro were the offensive engines for Braga. Blaylock led all scorers with 22 points, and Monteiro added a crucial 20. Monteiro was particularly efficient, shooting 66.7% from the field on 9 attempts. Blaylock, while taking more shots (47.1% FG), still provided significant scoring punch. Their combined scoring was over half of the team's total, highlighting their importance.
#
# 3.  **Broderick Robinson's Dual Threat Impact:** Broderick Robinson was a game-changer, not just for his scoring but for his playmaking. He contributed 17 points, but his 8 assists were a team-high, showcasing his ability to create for others. His exceptional 71.4% three-point shooting on 7 attempts opened up the floor and provided much-needed spacing. His ability to score and facilitate made him a critical offensive weapon.
#
# **Defensive Insights:**
#
# 4.  **Second Quarter Defensive Collapse:** The most glaring defensive issue was the second quarter, where Braga allowed 26 points. This was a significant drop in defensive intensity and execution, allowing the opponent to build a substantial lead. Without the opponent's boxscore, it's hard to pinpoint the exact cause, but this quarter represents a critical failure to contain the opposition's offense.
#
# 5.  **Active Hands and Rebounding Contributions:** Despite the second-quarter lapse, Braga showed positive defensive effort in other areas. Seydougou Fofana was a defensive force on the boards, grabbing a game-high 9 rebounds (2 offensive), and also contributed 2 steals and a block. Ricardo Monteiro also chipped in with 6 rebounds and 2 steals. The team's 7 total steals suggest an effort to disrupt the opponent's ball movement and create turnovers, which is a positive defensive indicator.

# %%
print(ba.practice_planner(False, 120, "Regular Highschool Court", "2 balls"))
# Out:
# Okay, let's craft a comprehensive 120-minute practice plan for Sporting Clube de Braga, focusing on building upon their strengths and addressing areas for improvement, using a regular high school court and two basketballs.
#
# **Overall Theme:** Enhancing offensive efficiency, solidifying defensive consistency, and developing clutch performance.
#
# **Time Allocation:**
#
# *   **Warm-up & Dynamic Movement (20 minutes)**
# *   **Offensive Skill Refinement & Efficiency (35 minutes)**
# *   **Defensive Intensity & Transition (35 minutes)**
# *   **Situational Scrimmage & Game Simulation (25 minutes)**
# *   **Cool-down & Review (5 minutes)**
#
# ---
#
# **Detailed Breakdown:**
#
# **I. Warm-up & Dynamic Movement (20 minutes)**
#
# *   **Dynamic Stretching & Agility (10 minutes):**
#     *   Light jogging, high knees, butt kicks, karaoke, lunges with twists, inchworms, bear crawls.
#     *   Focus on activating basketball-specific muscles and improving footwork.
#     *   Include short sprints and change-of-direction drills (e.g., zig-zag runs).
#
# *   **Ball Handling & Passing Warm-up (10 minutes - 2 Balls):**
#     *   **Two-Ball Dribbling:** Pound dribbles (alternating, simultaneous), crossovers, between-the-legs, behind-the-back. Focus on control, rhythm, and keeping the head up.
#     *   **Partner Passing:** Crisp chest passes, bounce passes, and overhead passes. Emphasize accuracy and catching with two hands.
#     *   **"Pass and Move":** Players spread out, pass to a moving teammate, and then cut to receive a return pass. This gets players moving and thinking about spacing and active feet.
#
# **II. Offensive Skill Refinement & Efficiency (35 minutes)**
#
# *   **Theme:** Improving shooting efficiency, developing secondary scoring options, and enhancing offensive decision-making.
#
# *   **Shooting Drills (15 minutes - 2 Balls):**
#     *   **"Form Shooting" (5 minutes):** Players work on their shooting form close to the basket, focusing on technique, balance, and follow-through. This is crucial for consistency.
#     *   **"Spot Shooting with Pressure" (10 minutes):**
#         *   Players pair up. One player rebounds and passes back to the shooter.
#         *   Designate 5-7 spots on the court. Players shoot a set number of shots (e.g., 10) from each spot.
#         *   **Added Pressure:** Introduce a "make it, take it" element or a "score X out of Y" challenge to simulate game pressure.
#         *   **Focus:** Shooting off the catch, quick release, and good form. Encourage players like Jesse Bingham II and Carlos Cardoso to work on their shooting consistency.
#
# *   **Offensive Movement & Decision Making (20 minutes):**
#     *   **"Pick and Roll Execution" (10 minutes):**
#         *   2 offensive players (ball handler, screener), 2 defensive players.
#         *   Focus on:
#             *   **Ball Handler:** Setting up the screen, reading the defense (roll, pop, drive), making the correct pass. Encourage Broderick Robinson and Delaney Blaylock to work on different reads.
#             *   **Screener:** Setting a solid screen, rolling to the basket or popping out for a shot.
#             *   **Defenders:** Communicating switches, hedging, or staying with their man.
#         *   Run this on both sides of the court.
#     *   **"Dribble Penetration and Kick-Out" (10 minutes):**
#         *   Players work on driving to the basket and making the correct decision: finishing, drawing a foul, or kicking out to an open shooter.
#         *   **Emphasis:** Players who are not primary scorers need to be looking to create for others or find their own shot when the opportunity arises. This helps develop offensive depth.
#
# **III. Defensive Intensity & Transition (35 minutes)**
#
# *   **Theme:** Building defensive resilience, improving communication, and excelling in transition defense.
#
# *   **Defensive Stance & Footwork Fundamentals (10 minutes):**
#     *   **"Defensive Slide Races":** Players line up on one side of the court and slide to the other. Focus on staying low, balanced, and not crossing feet. Add variations like sliding backward and defensive slides with a "closeout" at the end.
#     *   **"Mirror Drill":** Players pair up. One player moves laterally (simulating offensive movement), and the defender mirrors their movements without fouling. Emphasize staying between the offensive player and the basket.
#
# *   **Closeout & Containment Drills (15 minutes):**
#     *   **"Controlled Closeouts with Recovery":** Player A starts at the three-point line, Player B starts at the free-throw line. Player A dribbles towards the basket. Player B closes out hard, forcing Player A to pick up their dribble or make a difficult pass. Focus on the "sprint, chop, balance" sequence of a closeout and then recovering to a defensive stance.
#     *   **"1-on-1 Containment":** Players pair up. The offensive player tries to drive to the basket. The defender's goal is to prevent a clean drive and force them to a less advantageous spot or a contested shot. Emphasize using the body and staying in front. Rotate offensive and defensive players frequently.
#
# *   **Team Defense & Transition Defense (10 minutes):**
#     *   **"Shell Drill" (Half Court):** 4 offensive players (passing only, no dribbling) and 4 defensive players.
#         *   **Focus:** Ball-you-man awareness, help-side positioning, and *constant communication*.
#         *   **Coach calls out scenarios:** "Drive!", "Screen left!", "Pass to the wing!". Defenders must react and communicate.
#         *   **Emphasis:** Yelling "Help!", "Switch!", "I got ball!", "Recover!". This drill directly addresses the breakdown in the second quarter by forcing players to talk and react as a unit.
#     *   **"Transition Defense Drill":** Start with a made basket or a turnover. Players sprint back to get into defensive positions, communicating assignments and preventing easy fast-break points. This is crucial given the opponent's ability to score.
#
# **IV. Situational Scrimmage & Game Simulation (25 minutes)**
#
# *   **Theme:** Applying learned skills in game-like scenarios, focusing on clutch performance and overcoming adversity.
#
# *   **"Comeback Scrimmage" (10 minutes):**
#     *   Start the scrimmage with the opponent leading by 10-15 points (simulating the deficit from the second quarter).
#     *   Braga's objective is to come back and win.
#     *   **Coaching Focus:**
#         *   **Defense:** Emphasize sustained defensive intensity and communication for the entire 10 minutes. No letting up.
#         *   **Offense:** Encourage players to look for their shots and be aggressive, but also to make smart decisions and find open teammates. Reward good offensive plays from a variety of players.
#
# *   **"Clutch Time Scrimmage" (10 minutes):**
#     *   Start with a tied score or a 2-3 point lead for Braga.
#     *   Focus on executing in late-game scenarios: clock management, defensive stops, getting good shots, and free throws.
#     *   **Emphasis:** Players need to execute under pressure, similar to how they did in the fourth quarter.
#
# *   **"Free Throw Competition" (5 minutes):**
#     *   Players pair up. One shoots, the other rebounds.
#     *   Set a target number of makes (e.g., 5) from the line.
#     *   This adds a competitive element to free throw practice and reinforces the importance of this critical scoring area.
#
# **V. Cool-down & Review (5 minutes)**
#
# *   **Static Stretching:** Focus on major muscle groups (quads, hamstrings, calves, shoulders, back).
# *   **Team Huddle & Feedback:**
#     *   Briefly discuss what went well during practice, highlighting improvements in defensive communication and offensive balance.
#     *   Reiterate key takeaways regarding consistent effort and clutch performance.
#     *   Assign one specific offensive or defensive focus for each player to work on in the next practice.
#
# ---
#
# **Key Coaching Points Throughout Practice:**
#
# *   **Intensity and Focus:** Constantly push players to maintain a high level of intensity and focus throughout the entire practice.
# *   **Communication is Key:** Emphasize verbal cues on both offense and defense. No silent players on the court.
# *   **Effort Over Outcome:** Reward hustle plays, good defensive effort, and smart offensive decisions, even if the immediate result isn't perfect.
# *   **Player Development:** Encourage players like Jesse Bingham II, Carlos Cardoso, and Somtochukwu Dimanöchie to be more assertive offensively and look for their opportunities.
# *   **Repetition:** Ensure players get enough repetitions of each skill to build muscle memory and confidence.
#
# This plan aims to build on Braga's strengths (clutch performance, key scorers) while directly addressing their weaknesses (defensive lapses, offensive depth). The use of two balls allows for more touches and efficient drill execution.

# %%
print(ba.player_comp(["C. Cardoso", "R. Monteiro"]))
# Out:
# Alright, let's dive into some NBA player comparisons for Carlos Cardoso and Ricardo Monteiro, leveraging Basketball-Reference.com's wealth of data to justify the choices. It's important to remember that these are comparisons based on *style of play and statistical tendencies*, not necessarily predicting future NBA success.
#
# ---
#
# ### Carlos Cardoso
#
# **Basketball Reference Stats (from the provided boxscore):**
#
# *   **MIN:** 31:03
# *   **FGM:** 1, **FGA:** 7 (14.3%)
# *   **3PM:** 0, **3PA:** 5 (0.0%)
# *   **FTM:** 4, **FTA:** 4 (100.0%)
# *   **PTS:** 6
# *   **AST:** 2
# *   **REB:** 3
# *   **OREB:** 1
# *   **STL:** 0
# *   **BLK:** 0
# *   **TO:** 2
# *   **PF:** 3
#
# **Key Observations for Cardoso:**
#
# *   **Low Field Goal Percentage:** Very inefficient scorer from the field.
# *   **No Three-Point Threat:** Doesn't attempt or make threes.
# *   **High Free Throw Percentage:** Perfect from the line, indicating good touch.
# *   **Limited Scoring Volume:** Only 6 points on low usage.
# *   **Decent Rebounding for Position:** 3 rebounds, including 1 offensive.
# *   **Pass-First Mentality (relative to scoring):** 2 assists to 6 points.
# *   **High Minutes, Low Production:** Played over 31 minutes but contributed minimally offensively.
#
# **NBA Player Comparison: A Young, Developing, Defensive-Minded Big Man with Limited Offensive Polish**
#
# **Comparison: A young, developing version of a player like:**
#
# *   **Jarrett Allen (early career, before his offensive game expanded significantly):**
#     *   **Justification (Basketball Reference Lens):** Early in his career, Jarrett Allen was primarily known for his elite rim protection and rebounding. His offensive game was largely limited to dunks, put-backs, and free throws. He wasn't a volume scorer and often had low shooting percentages from the field when attempting jumpers.
#     *   **Cardoso's Fit:** Cardoso's 14.3% FG and 0% 3P% align with an offensive game that is not yet refined. His perfect free throw shooting is a positive sign, similar to how Allen's free throw ability indicated potential touch. While Cardoso's rebounding numbers aren't elite in this single game, his 1 offensive rebound suggests he's willing to battle inside. The high minutes with low scoring output also mirrors a player who is on the court for his defensive presence and energy, rather than his scoring prowess.
#
# *   **Mitchell Robinson (early career):**
#     *   **Justification (Basketball Reference Lens):** Mitchell Robinson is another prime example of a player whose NBA value was initially derived almost entirely from his athleticism, rebounding, and shot-blocking. His offensive game was very raw, relying on lobs and put-backs. His shooting percentages from the field could be inconsistent, and his three-point game was non-existent.
#     *   **Cardoso's Fit:** Similar to Allen, Robinson's early career profile fits Cardoso's current statistical output. The low scoring volume, high minutes for defensive impact, and lack of shooting range are all hallmarks. Cardoso's 1 block in this game, while not a huge sample, also points towards a potential defensive anchor role, much like Robinson.
#
# **Why not more established offensive bigs?** Players like Nikola Jokic, Joel Embiid, or even Bam Adebayo are far more offensively versatile and efficient than Cardoso's current stats suggest. Cardoso's game, based on this boxscore, is heavily weighted towards defense and hustle, with a very underdeveloped offensive skillset.
#
# ---
#
# ### Ricardo Monteiro
#
# **Basketball Reference Stats (from the provided boxscore):**
#
# *   **MIN:** 31:33
# *   **FGM:** 6, **FGA:** 9 (66.7%)
# *   **3PM:** 1, **3PA:** 3 (33.3%)
# *   **FTM:** 7, **FTA:** 10 (70.0%)
# *   **PTS:** 20
# *   **AST:** 2
# *   **REB:** 6
# *   **OREB:** 0
# *   **STL:** 2
# *   **BLK:** 0
# *   **TO:** 3
# *   **PF:** 3
#
# **Key Observations for Monteiro:**
#
# *   **High Efficiency:** Excellent 66.7% FG percentage.
# *   **Solid Scoring Volume:** 20 points, a team-high alongside Blaylock.
# *   **Decent Three-Point Shooting:** Made 1 of 3, showing some capability.
# *   **Good Free Throw Shooting:** 70% on 10 attempts, indicating he can get to the line and convert.
# *   **Good Rebounding for Position:** 6 rebounds, including 0 offensive.
# *   **Active Defender:** 2 steals.
# *   **Turnovers:** 3 turnovers, a slight concern.
#
# **NBA Player Comparison: A Versatile, Efficient Big Man with Scoring Prowess and Defensive Activity**
#
# **Comparison: A player like:**
#
# *   **Domantas Sabonis (early career, particularly his time with OKC):**
#     *   **Justification (Basketball Reference Lens):** Sabonis, especially in his early years, was a highly efficient scorer from the post and mid-range. He was a strong rebounder and showed flashes of playmaking ability. His three-point shooting was not a primary weapon, but he could hit them when open. He was also active defensively, contributing steals and blocks.
#     *   **Monteiro's Fit:** Monteiro's 66.7% FG% is very reminiscent of Sabonis's efficiency. His 20 points on 9 shots show he's a capable scorer who can get buckets efficiently. The 6 rebounds and 2 steals indicate a well-rounded game. While Sabonis's assist numbers were often higher, Monteiro's 2 assists show he's not just a scorer but can contribute to the offense. The 70% free throw shooting is also in line with a developing big man who can get to the line.
#
# *   **Christian Wood (when playing as a more traditional big):**
#     *   **Justification (Basketball Reference Lens):** Christian Wood, particularly in his earlier stints where he played more as a center, demonstrated impressive scoring efficiency from various spots on the floor. He could score inside, hit mid-range jumpers, and occasionally step out for threes. He was also a solid rebounder and showed defensive activity.
#     *   **Monteiro's Fit:** Monteiro's efficiency (66.7% FG) and scoring volume (20 points) align well with Wood's capabilities as a scorer. His ability to hit a three (33.3%) adds another dimension that Wood also possesses. The 6 rebounds and 2 steals suggest a player who contributes across the board. Monteiro's 3 turnovers are something to monitor, as Wood has also had games with higher turnover rates when handling the ball more.
#
# **Why not a pure stretch-five?** While Monteiro made a three, his volume (1 of 3) and overall game suggest he's not solely a floor-spacing big. He's more of a versatile scorer who can hit from outside, rather than a dedicated "stretch-five" like a prime JJ Redick or a modern-day Joe Ingles (though Ingles is more of a forward).
#
# ---
#
# **Important Caveats:**
#
# *   **Sample Size:** These comparisons are based on a single game's boxscore. A larger sample size would be needed for more definitive analysis.
# *   **Role and System:** Player roles and team systems heavily influence statistics. These comparisons assume a similar role and offensive/defensive scheme.
# *   **Development:** NBA players evolve. These comparisons are based on statistical profiles that may represent a player's current stage or a specific period in their career.
#
# These comparisons aim to highlight the *statistical archetypes* that Cardoso and Monteiro currently fit, based on the provided data.
