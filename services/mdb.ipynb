# %%
# %pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/910.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/910.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/910.9 kB ? eta -:--:--
#    --------------------- ---------------- 524.3/910.9 kB 882.6 kB/s eta 0:00:01
#    --------------------- ---------------- 524.3/910.9 kB 882.6 kB/s eta 0:00:01
#    --------------------- ---------------- 524.3/910.9 kB 882.6 kB/s eta 0:00:01
#    ---------------------------------------- 910.9/910.9 kB 728.1 kB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
# ...

# %%
from dotenv import load_dotenv

# %%
import sys, os

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

# %%
from utils.mongo_utils import store_boxscore
import json
from pymongo import MongoClient

# %%
load_dotenv()
# Out:
# True

# %%
with open("test_jsons/fpb_braga.json", "r") as f:
    td=json.load(f)

# %%
td
# Out:
# {'Braga': {'Team_Name': 'Sporting Clube de Braga',
#   'Home_Game': True,
#   'Scores': [{'Total': [{'Home': 83}, {'Away': 80}]},
#    {'1Q': [{'Home': 22}, {'Away': 21}]},
#    {'2Q': [{'Home': 11}, {'Away': 26}]},
#    {'3Q': [{'Home': 23}, {'Away': 15}]},
#    {'4Q': [{'Home': 27}, {'Away': 18}]}],
#   'Players': [{'Number': 2,
#     'Player': 'Delaney Blaylock',
#     'MIN': '28:41',
#     'FGM': 8,
#     'FGA': 17,
#     'FG%': 47.1,
#     '3PM': 3,
#     '3PA': 10,
#     '3P%': 30.0,
#     'FTM': 3,
#     'FTA': 4,
#     'FT%': 75.0,
#     'PTS': 22,
#     'AST': 2,
#     'REB': 4,
#     'OREB': 0,
#     'STL': 1,
#     'BLK': 0,
#     'TO': 3,
#     'PF': 4,
#     '+-': 14},
#    {'Number': 3,
#     'Player': 'Jesse Bingham Ii',
#     'MIN': '25:00',
#     'FGM': 2,
#     'FGA': 6,
#     'FG%': 33.3,
#     '3PM': 0,
#     '3PA': 2,
#     '3P%': 0.0,
#     'FTM': 0,
#     'FTA': 2,
#     'FT%': 0.0,
#     'PTS': 4,
#     'AST': 3,
#     'REB': 2,
#     'OREB': 1,
# ...

# %%
# %pip install dnspython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(sys.executable)
# Out:
# c:\Users\jpalo\anaconda3\envs\Capstone_Project\python.exe

# %%
mongo_uri = os.getenv("MONGODB_URI")
if not mongo_uri:
    print("⚠️ MONGODB_URI not found in .env file")
    print("💡 This is optional - vector search concepts work without MongoDB")
else:
    mongo_client = MongoClient(mongo_uri)
    db = mongo_client["SYS"]
    collection = db["boxscore"]
    
    print("✅ Connected to MongoDB")
    print(f"📊 Database: {db.name}")
    print(f"📊 Collection: {collection.name}")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[33], line 6
#       4     print("💡 This is optional - vector search concepts work without MongoDB")
#       5 else:
# ----> 6     mongo_client = MongoClient(mongo_uri)
#       7     db = mongo_client["SYS"]
#       8     collection = db["boxscore"]
#
# File c:\Users\jpalo\anaconda3\envs\Capstone_Project\Lib\site-packages\pymongo\synchronous\mongo_client.py:891, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     888     self._init_background()
#     890 if _IS_SYNC and connect:
# --> 891     self._get_topology()
#
# File c:\Users\jpalo\anaconda3\envs\Capstone_Project\Lib\site-packages\pymongo\synchronous\mongo_client.py:1758, in MongoClient._get_topology(self)
#    1756 if not self._opened:
#    1757     if self._resolve_srv_info["is_srv"]:
# ...

# %%
#uri = "mongodb+srv://SYS:sys@cluster0.wzxmsaq.mongodb.net/?retryWrites=true&w=majority"
uri = "mongodb+srv://SYS:sys@cluster0.wzxmsaq.mongodb.net/?appName=Cluster0"
client = MongoClient(uri)
print(client.list_database_names())
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[28], line 3
#       1 #uri = "mongodb+srv://SYS:sys@cluster0.wzxmsaq.mongodb.net/?retryWrites=true&w=majority"
#       2 uri = "mongodb+srv://SYS:sys@cluster0.wzxmsaq.mongodb.net/?appName=Cluster0"
# ----> 3 client = MongoClient(uri)
#       4 print(client.list_database_names())
#
# File c:\Users\jpalo\anaconda3\envs\Capstone_Project\Lib\site-packages\pymongo\synchronous\mongo_client.py:891, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     888     self._init_background()
#     890 if _IS_SYNC and connect:
# --> 891     self._get_topology()
#
# File c:\Users\jpalo\anaconda3\envs\Capstone_Project\Lib\site-packages\pymongo\synchronous\mongo_client.py:1758, in MongoClient._get_topology(self)
#    1756 if not self._opened:
# ...

# %%
store_boxscore(td, "SCB", "IMO")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 store_boxscore(td, "SCB", "IMO")
#
# File c:\Users\jpalo\Desktop\OneDrive - Personal\Ambiente de Trabalho\Joao\Github\Github_JP\CapstoneProject\utils\mongo_utils.py:43, in store_boxscore(boxscore, team_name, opponent)
#      38 def store_boxscore(boxscore: dict, team_name: str, opponent):
#      39     """
#      40     Store a boxscore in MongoDB using the init_mongo() collection.
#      41     Returns the inserted document ID.
#      42     """
# ---> 43     collection = init_mongo()
#      45     doc = {
#      46         "team_name": team_name,
#      47         "opponent": opponent,
#      48         "timestamp": pd.Timestamp.now(),  # optional
#      49         "boxscore": boxscore
#      50     }
#      52     result = collection.insert_one(doc)
#
# ...
